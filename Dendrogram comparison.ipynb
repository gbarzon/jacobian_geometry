# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

from utils import distance
from utils import CommonFunctions as CF

import importlib
importlib.reload(distance)
importlib.reload(CF)

import networkx as nx

# %%
def create_graph_comms(N, num_groups, p_in, p_out):
    nodes_per_group = N//num_groups;
    print('Block model probs: in %f - out %f' % (p_in, p_out))

    G_gn = nx.planted_partition_graph(num_groups, nodes_per_group, p_in, p_out, directed=False)

    while nx.is_connected(G_gn) == 0:
        print('The network should be in a single component. New trial!')
        G_gn = nx.planted_partition_graph(num_groups, nodes_per_group, p_in, p_out, directed=False)

    infoG_gn = ['GN',k_out]

    print('Mean degree', np.mean(list(dict(G_gn.degree()).values())))
    
    return G_gn

# %%
N = 128
num_groups = 4

# %%
p_in=0.7, p_out=0.01

G_gn = create_graph_comms(N, num_groups, p_in, p_out)
A_gn = nx.to_numpy_array(G_gn)

G_rand = nx.random_reference(G_gn, niter=1)
A_rand = nx.to_numpy_array(G_rand)
# Out:
# Block model probs: in 0.700000 - out 0.010000
# Mean degree 22.421875

# %%
nx.draw(G_gn)

# %%
G_fc = nx.fast_gnp_random_graph(N, p=1)
A_fc = nx.to_numpy_array(G_fc)

# %%
name=f'N_{N}_C_{num_groups}_pin_{p_in}_pout_{p_out}.txt'

# %% [markdown]
# # Diffusion distance

# %%
res_gn = distance.diffusion_distance(A_gn, args=[1, 1], name=name)
# Out:
# DIFFUSION DISTANCE
# - Compute laplacian...
# 1 1
# - Compute average distance...
#   0%|          | 0/128 [00:00<?, ?it/s]
# - Compute hierarchical clustering with method ward...

# %%
res_gn = distance.diffusion_distance(A_gn, args=[5, 1])
# Out:
# DIFFUSION DISTANCE
# - Compute average distance...
# 5 1
#   0%|          | 0/128 [00:00<?, ?it/s]
# - Compute hierarchical clustering with method ward...

# %%
res_rand = distance.diffusion_distance(A_rand)
# Out:
# DIFFUSION DISTANCE
# - Compute average distance...
# 1.0 1.0
#   0%|          | 0/128 [00:00<?, ?it/s]
# - Compute hierarchical clustering with method ward...

# %%
res_rand = distance.diffusion_distance(A_fc)
# Out:
# DIFFUSION DISTANCE
# - Compute average distance...
# 1.0 1.0
#   0%|          | 0/128 [00:00<?, ?it/s]
# - Compute hierarchical clustering with method ward...

# %% [markdown]
# # Noisy voter model

# %%
res_nvm = distance.jacobian_distance(A_gn, 'NoisyVM', norm=True, args=[0., 1., 1.], name=name)
# Out:
# JACOBIAN DISTANCE
# Dynamics: NoisyVM
# Normalizing jacobian - $\lambda_{max}=$1.283095877998824
# - Compute average distance...
#   0%|          | 0/128 [00:00<?, ?it/s]
# - Compute hierarchical clustering with method ward...

# %%
res_nvm = distance.jacobian_distance(A_gn, 'NoisyVM', norm=True, args=[0, 5, 1], name=name)
# Out:
# JACOBIAN DISTANCE
# Dynamics: NoisyVM
# Normalizing jacobian - $\lambda_{max}=$5.283095877998843
# - Compute average distance...
#   0%|          | 0/128 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-178-d282a5473647> in <module>
# ----> 1 res_nvm = distance.jacobian_distance(A_gn, 'NoisyVM', norm=True, args=[0, 5, 1])
#
# ~/Network_geometry/utils/distance.py in jacobian_distance(mat, dynamics, norm, show, method, args, name)
#     139     # Compute average jacobian distance
#     140     print('- Compute average distance...')
# --> 141     avg_dd = average_distance(jacobian)
#     142
#     143     # Compute hierarchical clustering
#
# ~/Network_geometry/utils/distance.py in average_distance(mat_enr, tmax, display, return_snapshot)
#      46     if display:
#      47         for t in tqdm(range(1, tmax+1)):
# ---> 48             d_t_ij[t-1] = compute_distance(mat_enr, t)
#      49     else:
#      50         for t in range(1, tmax+1):
#
# ~/Network_geometry/utils/distance.py in compute_distance(mat_enr, t)
#      26 def compute_distance(mat_enr, t):
#      27     num_nodes = len(mat_enr)
# ---> 28     expM = expm(mat_enr*t)
#      29
#      30     d_ij = np.zeros((num_nodes,num_nodes))
#
# /usr/local/lib/python3.6/dist-packages/scipy/linalg/matfuncs.py in expm(A)
#     253     # Input checking and conversion is provided by sparse.linalg.expm().
#     254     import scipy.sparse.linalg
# --> 255     return scipy.sparse.linalg.expm(A)
#     256
#     257
#
# /usr/local/lib/python3.6/dist-packages/scipy/sparse/linalg/matfuncs.py in expm(A)
#     589             [  0.        ,   0.        ,  20.08553692]])
#     590     """
# --> 591     return _expm(A, use_exact_onenorm='auto')
#     592
#     593
#
# /usr/local/lib/python3.6/dist-packages/scipy/sparse/linalg/matfuncs.py in _expm(A, use_exact_onenorm)
#     671     s = s + _ell(2**-s * h.A, 13)
#     672     U, V = h.pade13_scaled(s)
# --> 673     X = _solve_P_Q(U, V, structure=structure)
#     674     if structure == UPPER_TRIANGULAR:
#     675         # Invoke Code Fragment 2.1.
#
# /usr/local/lib/python3.6/dist-packages/scipy/sparse/linalg/matfuncs.py in _solve_P_Q(U, V, structure)
#     707         return spsolve(Q, P)
#     708     elif structure is None:
# --> 709         return solve(Q, P)
#     710     elif structure == UPPER_TRIANGULAR:
#     711         return solve_triangular(Q, P)
#
# /usr/local/lib/python3.6/dist-packages/scipy/linalg/basic.py in solve(a, b, sym_pos, lower, overwrite_a, overwrite_b, debug, check_finite, assume_a, transposed)
#     211         gecon, getrf, getrs = get_lapack_funcs(('gecon', 'getrf', 'getrs'),
#     212                                                (a1, b1))
# --> 213         lu, ipvt, info = getrf(a1, overwrite_a=overwrite_a)
#     214         _solve_check(n, info)
#     215         x, info = getrs(lu, ipvt, b1,
#
# KeyboardInterrupt:

# %% [markdown]
# # Jacobian epidemics

# %%
params = [[1, 1],
          [5, 1],
          [10, 1],
          [50, 1],
          [100, 1]]

# %%
res_epi = distance.jacobian_distance(A_gn, 'Epidemics', norm=True, args=[1, 5])
# Out:
# JACOBIAN DISTANCE
# Dynamics: Epidemics
# Normalizing jacobian - $\lambda_{max}=$31.733905737734965
# - Compute average distance...
#   0%|          | 0/128 [00:00<?, ?it/s]
# - Compute hierarchical clustering with method ward...

# %%
for param in params:
    res_epi = distance.jacobian_distance(A_gn, 'Epidemics', norm=True, args=param, name=name)
# Out:
# JACOBIAN DISTANCE
# Dynamics: Epidemics
# Normalizing jacobian - $\lambda_{max}=$30.646350267797647
# - Compute average distance...
#   0%|          | 0/128 [00:00<?, ?it/s]
# - Compute hierarchical clustering with method ward...
# JACOBIAN DISTANCE
# Dynamics: Epidemics
# Normalizing jacobian - $\lambda_{max}=$29.389616856479826
# - Compute average distance...
#   0%|          | 0/128 [00:00<?, ?it/s]
# - Compute hierarchical clustering with method ward...
# JACOBIAN DISTANCE
# Dynamics: Epidemics
# Normalizing jacobian - $\lambda_{max}=$28.136724398532206
# - Compute average distance...
#   0%|          | 0/128 [00:00<?, ?it/s]
# - Compute hierarchical clustering with method ward...
# JACOBIAN DISTANCE
# Dynamics: Epidemics
# Normalizing jacobian - $\lambda_{max}=$56.090502689108234
# - Compute average distance...
#   0%|          | 0/128 [00:00<?, ?it/s]
# - Compute hierarchical clustering with method ward...
# JACOBIAN DISTANCE
# Dynamics: Epidemics
# Normalizing jacobian - $\lambda_{max}=$106.09050268910771
# - Compute average distance...
#   0%|          | 0/128 [00:00<?, ?it/s]
# - Compute hierarchical clustering with method ward...

# %%
res_epi = distance.jacobian_distance(A_gn, 'Epidemics', norm=True, args=[5, 1])
# Out:
# JACOBIAN DISTANCE
# Dynamics: Epidemics
# Normalizing jacobian - $\lambda_{max}=$29.389616856479712
# - Compute average distance...
#   0%|          | 0/128 [00:00<?, ?it/s]
# - Compute hierarchical clustering with method ward...

# %%
res_epi = distance.jacobian_distance(A_gn, 'Epidemics', norm=True, args=[10, 1])
# Out:
# JACOBIAN DISTANCE
# Dynamics: Epidemics
# Normalizing jacobian - $\lambda_{max}=$28.136724398532277
# - Compute average distance...
#   0%|          | 0/128 [00:00<?, ?it/s]
# - Compute hierarchical clustering with method ward...

# %%
res_epi = distance.jacobian_distance(A_gn, 'Epidemics', norm=True, args=[5, 1])
# Out:
# JACOBIAN DISTANCE
# Dynamics: Epidemics
# Normalizing jacobian - $\lambda_{max}=$29.38961685647984
# - Compute average distance...
#   0%|          | 0/128 [00:00<?, ?it/s]
# - Compute hierarchical clustering with method ward...

# %% [markdown]
# # Comparison with R

# %%
from rpy2 import robjects

# %%
robjects.r('''
    add_nums <- function(x, y) {
        return(x + y)
    }
    
    print(add_nums(x = 5, y = 10))
    print(add_nums(x = 10, y = 20))
''')
# Out:
# [1] 15
# [1] 30
# <rpy2.robjects.vectors.FloatVector object at 0x7f141cf97ac8> [RTYPES.REALSXP]
# R classes: ('numeric',)
# [30.000000]

# %%
my_obj = robjects.r('''
    library(dendextend)
    library(corrplot)
    
    ### DEFINE NAMES
    names <- c('results/diffusion_N_128_C_4_pin_0.7_pout_0.01.txt',
                'results/Epidemics_[1, 1]_N_128_C_4_pin_0.7_pout_0.01.txt',
                'results/Epidemics_[5, 1]_N_128_C_4_pin_0.7_pout_0.01.txt',
                'results/Epidemics_[10, 1]_N_128_C_4_pin_0.7_pout_0.01.txt',
                'results/Epidemics_[50, 1]_N_128_C_4_pin_0.7_pout_0.01.txt',
                'results/Epidemics_[100, 1]_N_128_C_4_pin_0.7_pout_0.01.txt')
    
    params <- c('Diffusion',
                'Epi, mu=1',
                'Epi, mu=5',
                'Epi, mu=10',
                'Epi, mu=50',
                'Epi, mu=100')
    nn <- length(names)
    
    mats <- list()
    dends <- dendlist()
        
    for (i in seq_along(names)){
        print(name)
        
        # Load mat
        mat <- scan(names[i])
        mat <- matrix(mat, ncol = 128, byrow = TRUE)
        mat <- as.dist(mat)
        
        # Store mat
        mats[[i]] <- mat
        
        # Compute dendrogram
        dend <- hclust(mat, method = "average")
        dend <- as.dendrogram(dend)
        
        # Store dend
        dends[[i]] <- dend
    }
    
    ### PLOT CORRPLOT
    png("corrplot.png") # open image
    #jpeg('corrplot.jpg') pdf("corrplot.pdf")
    cor_mat <- cor.dendlist(dends) # compute correlation matrix
    colnames(cor_mat) <- params # set labels
    rownames(cor_mat) <- params
    corrplot(cor_mat, method = 'circle', type = 'upper', diag = FALSE, addCoef.col ='red', number.cex = 1.2)
    dev.off()
''')
# Out:
# [1] "results/Epidemics_[100, 1]_N_128_C_4_pin_0.7_pout_0.01.txt"
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Read 16384 items
# [1] "results/Epidemics_[100, 1]_N_128_C_4_pin_0.7_pout_0.01.txt"
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Read 16384 items
# [1] "results/Epidemics_[100, 1]_N_128_C_4_pin_0.7_pout_0.01.txt"
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Read 16384 items
# [1] "results/Epidemics_[100, 1]_N_128_C_4_pin_0.7_pout_0.01.txt"
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Read 16384 items
# [1] "results/Epidemics_[100, 1]_N_128_C_4_pin_0.7_pout_0.01.txt"
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Read 16384 items
# [1] "results/Epidemics_[100, 1]_N_128_C_4_pin_0.7_pout_0.01.txt"
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Read 16384 items

# %% [markdown]
# # Best partition

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster, cophenet
from scipy.spatial.distance import squareform

# %%
dd, Z = res_rand[0], res_rand[1]

# %%
c, coph_dists = cophenet(Z, squareform(dd))

# %%
c, coph_dists
# Out:
# (0.991155865101784,
#  array([0.0110092 , 0.0110092 , 0.01520363, ..., 0.00679255, 0.01226445,
#         0.01226445]))

# %%
from sklearn.metrics import silhouette_score
silhouette_score(dd, Z, metric="precomputed")

# %%
n_clust = np.arange(2,40)
scores = np.zeros(len(n_clust))

for i, clust in enumerate(n_clust):
    comms = fcluster(Z, criterion='maxclust', t=clust)
    
    scores[i] = silhouette_score(dd, comms, metric="precomputed")
    
best = np.argmax(scores)

# %%
plt.plot(n_clust, scores, 'o-')
plt.plot(n_clust[best], scores[best], 'o')
plt.show()
